# %% [markdown]
# # Exploring Teacher Conflicts

# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import json

# %%
from plot import plot_phase, plot_stats, plot_training, plot_stats_phase, get_test, get_name

# %% [markdown]
# ## Single Teachers

# %%
fig, axs = plt.subplots(2, 2, figsize=(16, 12))
# tests_1t = ['adam', 'rmsprop', 'radam', '1t_adam', '1t_rmsprop', '1t_nadam', '1t_radam']
tests_1t = ['adam', 'rmsprop', 'radam', '1t_adam', '1t_rmsprop', '1t_radam']
plot_stats(tests_1t, axs)
axs[0][1].set_ylim(-3.5, -1.0)
axs[0][0].set_ylim(-6, -0.5)
axs[1][0].set_ylim(0.94, 1.0)
axs[1][1].set_ylim(0.94, 0.99)
# Out:
# (0.94, 0.99)

# %%
fig, axs = plt.subplots(1, 2, figsize=(16, 6))
plot_stats_phase(tests_1t, axs)
axs[0].set_xlim(0.980, 1.00)
axs[0].set_ylim(0.980, 0.989)
axs[1].set_xlim(-5.0, -2.0)
axs[1].set_ylim(-3.3, -2.6)
# Out:
# (-3.3, -2.6)

# %%
fig, axs = plt.subplots(1, 1, figsize=(8, 6))

# %%
fig, axs = plt.subplots(1, 1, figsize=(8, 6))
plot_training(["1t_adam", "1t_rmsprop", "1t_nadam", "1t_radam"], axs, meta=False)

# %% [markdown]
# ## Paired Teachers

# %%
fig, axs = plt.subplots(2, 2, figsize=(16, 12))
tests_2t = ['adam', 'rmsprop', 'radam', '2t_adam_rmsprop', '2t_rmsprop_radam', '2t_adam_radam']
plot_stats(tests_2t, axs)
axs[0][1].set_ylim(-3.5, -1.0)
axs[0][0].set_ylim(-6, -0.5)
axs[1][0].set_ylim(0.94, 1.0)
axs[1][1].set_ylim(0.94, 0.995)
# Out:
# (0.94, 0.995)

# %%
fig, axs = plt.subplots(1, 2, figsize=(16, 6))
plot_stats_phase(tests_2t, axs)
axs[0].set_xlim(0.980, 1.00)
axs[0].set_ylim(0.983, 0.99)
axs[1].set_xlim(-6.0, -2.0)
axs[1].set_ylim(-3.45, -2.6)
# Out:
# (-3.45, -2.6)

# %%
fig, axs = plt.subplots(1, 2, figsize=(16, 6))
plot_training(["2t_adam_rmsprop", "2t_rmsprop_radam", "2t_adam_radam"], axs, meta=True)
