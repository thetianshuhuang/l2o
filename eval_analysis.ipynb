# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

import plot

# %%
fig, axs = plt.subplots(2, 1, figsize=(16, 6))
plot.plot_stats_batch(["adam", "scale_20", "scale_mlp"], axs, end=500, sma=51)
# Out:
# C:\Users\Tianshu Huang\Documents\projects\l2o\plot\plot.py:73: RuntimeWarning: invalid value encountered in log
#   axs[0], x[:end], np.log(d["batch_loss"][:, :end]),

# %%
fig, axs = plt.subplots(2, 1, figsize=(16, 6))
plot.plot_stats_batch(["adam", "rnnprop_20", "rnnprop_20_adam"], axs, end=500, sma=51)
axs[0].set_ylim(-2.5, 0)
axs[1].set_ylim(0.6, 1)
# Out:
# (0.6, 1)

# %%
fig, axs = plt.subplots(2, 1, figsize=(16, 6))
plot.plot_stats_batch(["adam", "rnnprop_20", "rnnprop_20_adam", "rnnprop_20_adam_rmsprop"], axs, end=500, sma=51)
axs[0].set_ylim(-2.5, 0)
axs[1].set_ylim(0.6, 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5b8ba35d27a5> in <module>
# ----> 1 fig, axs = plt.subplots(2, 1, figsize=(16, 6))
#       2 plot.plot_stats_batch(["adam", "rnnprop_20", "rnnprop_20_adam", "rnnprop_20_adam_rmsprop"], axs, end=500, sma=51)
#       3 axs[0].set_ylim(-2.5, 0)
#       4 axs[1].set_ylim(0.6, 1)
#
# NameError: name 'plt' is not defined

# %%
fig, axs = plt.subplots(2, 1, figsize=(16, 6))
plot.plot_stats_batch(["choice_20", "choice_50", "choice_100", "adam"], axs, end=1000, use_time=False, sma=51)
axs[0].set_ylim(-2.5, 1)
axs[1].set_ylim(0.8, 1)
# Out:
# (0.8, 1)

# %%
fig, axs = plt.subplots(2, 1, figsize=(16, 6))
plot.plot_stats_batch(["adam", "choice_hard", "choice_hard_50"], axs, end=1000, sma=51)
axs[0].set_ylim(-2.5, 1)
axs[1].set_ylim(0.8, 1)
# Out:
# (0.8, 1)

# %%
fig, axs = plt.subplots(2, 1, figsize=(16, 6))
plot.plot_stats_batch(["adam", "choice_mlp", "choice_mlp_deeper"], axs, end=2000, sma=51)
axs[0].set_ylim(-3.5, 0)
axs[1].set_ylim(0.9, 1)
# Out:
# (0.9, 1)

# %%
fig, axs = plt.subplots(2, 1, figsize=(16, 6))
plot.plot_stats_batch(["adam", "choice_sigmoid", "choice_20", "choice_leaky_relu"], axs, end=2000, sma=51)
axs[0].set_ylim(-2.5, 0)
axs[1].set_ylim(0.6, 1)
# Out:
# (0.6, 1)

# %%
fig, axs = plt.subplots(2, 1, figsize=(16, 6))
plot.plot_stats_batch(["adam", "choice_sigmoid", "choice_100", "choice_mlp", "choice_mlp_deeper"], axs, end=2000, sma=51)
axs[0].set_ylim(-3.5, 0)
axs[1].set_ylim(0.6, 1)
# Out:
# (0.6, 1)

# %%
fig, axs = plt.subplots(2, 1, figsize=(16, 6))
plot.plot_stats_batch(["adam", "choice_sigmoid", "choice_100", "choice_mlp", "choice_mlp_deeper"], axs, end=0, sma=51)
axs[0].set_ylim(-7, -1)
axs[1].set_ylim(0.95, 1.01)
# Out:
# (0.95, 1.01)

# %%
fig, axs = plt.subplots(2, 1, figsize=(16, 6))
plot.plot_stats_batch(["adam", "choice_20", "choice_wider", "choice_bigger"], axs, end=1000, use_time=False, sma=51)
axs[0].set_ylim(-2.5, 1)
axs[1].set_ylim(0.8, 1)
# Out:
# (0.8, 1)

# %%
fig, axs = plt.subplots(2, 1, figsize=(16, 6))
plot.plot_stats_batch(["adam", "rnnprop_20", "rnnprop_20_adam"], axs, end=1000, use_time=False, sma=51)
axs[0].set_ylim(-2.5, 1)
axs[1].set_ylim(0.8, 1)
# Out:
# (0.8, 1)

# %%
fig, axs = plt.subplots(2, 1, figsize=(16, 6))
plot.plot_stats_batch(["adam", "choice_20", "choice_mlp", "choice_sigmoid", "choice_dbg", "choice_dbg2"], axs, end=0, use_time=True, sma=51)
axs[0].set_ylim(-7, -1)
axs[1].set_ylim(0.8, 1.01)
# Out:
# (0.8, 1.01)

# %%
fig, axs = plt.subplots(2, 1, figsize=(16, 6))
plot.plot_stats_batch(["adam", "rnnprop_mlp_adam", "rnnprop_mlp_adam_rmsprop"], axs, end=0, use_time=False, sma=51)
# axs[0].set_ylim(-7, -1)
# axs[1].set_ylim(0.8, 1.01)

# %%
fig, axs = plt.subplots(2, 1, figsize=(16, 6))
plot.plot_stats_batch(["adam", "choice_20", "rnnprop_mlp_adam_rmsprop", "rnnprop_20_adam_rmsprop"], axs, end=0, use_time=False, sma=51)
# axs[0].set_ylim(-7, -1)
# axs[1].set_ylim(0.8, 1.01)

# %%
fig, axs = plt.subplots(2, 1, figsize=(16, 6))
plot.plot_stats_batch(["adam", "choice_nrscale", "rnnprop_mlp_adam_rmsprop_nrscale", "rnnprop_20_adam_rmsprop_nrscale"], axs, end=500, use_time=False, sma=51)

# %%
fig, axs = plt.subplots(2, 1, figsize=(16, 6))
plot.plot_stats_batch(["adam", "scale_20"], axs, end=0, use_time=False, sma=51)

# %%
fig, axs = plt.subplots(2, 1, figsize=(16, 6))
plot.plot_stats_batch(["adam", "choice_noscale", ""], axs, end=500, use_time=False, sma=1)
axs[0].axhline(-1.52)
