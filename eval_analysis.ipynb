# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

import plot

# %%
fig, axs = plt.subplots(2, 1, figsize=(16, 6))
plot.plot_stats_batch(["choice_20", "choice_50", "choice_100", "adam"], axs, end=1000, use_time=False, sma=51)
axs[0].set_ylim(-2.5, 1)
axs[1].set_ylim(0.8, 1)
# Out:
# (0.8, 1)

# %%
fig, axs = plt.subplots(2, 1, figsize=(16, 6))
plot.plot_stats_batch(["choice_hard", "choice_hard_50", "adam"], axs, end=1000, sma=51)
axs[0].set_ylim(-2.5, 1)
axs[1].set_ylim(0.8, 1)
# Out:
# (0.8, 1)

# %%
fig, axs = plt.subplots(2, 1, figsize=(16, 6))
plot.plot_stats_batch(["choice_mlp", "adam"], axs, end=2000, sma=51)
axs[0].set_ylim(-3.5, 0)
axs[1].set_ylim(0.9, 1)
# Out:
# (0.9, 1)
