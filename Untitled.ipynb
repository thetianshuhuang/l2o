# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

import plot

# %%
fig, axs = plt.subplots(1, 1, figsize=(8, 6))
plot.plot_phase(["adam", "choice-20x25C", "choice-20x25M"], axs, loss=True)
axs.legend()

# %%
fig, axs = plt.subplots(1, 2, figsize=(16, 6))
plot.plot_phase(["adam", "choice-20x25C", "choice-20x25M"], axs[0], loss=True)
plot.plot_phase(["adam", "rnnprop-20x25C", "rnnprop-20x25M"], axs[1], loss=True)
axs[0].legend()
axs[1].legend()

# %%
fig, axs = plt.subplots(2, 2, figsize=(16, 12))
plot.plot_stats(["adam", "choice-20x25C", "choice-20x25M"], axs)

# %%
fig, axs = plt.subplots(2, 2, figsize=(16, 12))
plot.plot_stats(["adam", "rnnprop-20x25C", "rnnprop-20x25M"], axs)
