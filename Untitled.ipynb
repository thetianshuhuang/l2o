# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

import plot

# %%
fig, axs = plt.subplots(2, 2, figsize=(16, 12))
plot.plot_phase(["adam", "choice_20", "choice_50", "choice_100"], axs[0][0], loss=True)
plot.plot_phase(["adam", "choice_hard", "choice_hard_50"], axs[0][1], loss=True)
plot.plot_phase(["adam", "choice_20", "choice_sigmoid", "choice_leaky_relu"], axs[1][0], loss=True)
plot.plot_phase(["adam", "choice_20", "choice_wider", "choice_bigger"], axs[1][1], loss=True)
fig.tight_layout()

for row in axs:
    for ax in row:
        ax.plot([-4, 0], [-4, 0], color='gray')
        ax.legend()
        ax.set_xlim(-3, -1)
        ax.set_ylim(-3, -1)

# %%
fig, axs = plt.subplots(1, 1, figsize=(8, 6))
plot.plot_phase(["choice_mlp", "choice_mlp_deeper", "adam"], axs, loss=True)
axs.legend()
axs.set_xlim(-6, -2.5)
axs.set_ylim(-3.5, -2.5)
# Out:
# (-3.5, -2.5)

# %%
fig, axs = plt.subplots(1, 1, figsize=(8, 6))
plot.plot_phase(["adam", "rnnprop_20", "rnnprop_20_adam"], axs, loss=True)
axs.legend()
# axs.set_xlim(-6, -2.5)
# axs.set_ylim(-3.5, -2.5)

# %%
fig, axs = plt.subplots(1, 1, figsize=(8, 6))
plot.plot_phase(["adam", "choice_mlp", "choice_dbg", "choice_dbg2"], axs, loss=True)
axs.legend()
# axs.set_xlim(-6, -2.5)
# axs.set_ylim(-3.5, -2.5)

# %%
fig, axs = plt.subplots(1, 1, figsize=(8, 6))
plot.plot_phase(["adam", "rnnprop_20_adam", "rnnprop_20_adam_rmsprop"], axs, loss=True)
axs.legend()
# axs.set_xlim(-6, -2.5)
# axs.set_ylim(-3.5, -2.5)

# %%
fig, axs = plt.subplots(2, 2, figsize=(16, 12))
plot.plot_stats(["choice_20", "choice_50", "choice_100", "choice_hard", "choice_mlp", "choice_mlp_deeper", "adam"], axs)

# %%
fig, axs = plt.subplots(2, 2, figsize=(16, 12))
plot.plot_stats(["rnnprop_20", "rnnprop_20_adam", "rnnprop_20_adam_rmsprop", "adam"], axs)

# %%
fig, axs = plt.subplots(2, 2, figsize=(16, 12))
plot.plot_stats(["rnnprop_mlp_adam", "rnnprop_mlp_adam_rmsprop", "adam"], axs)

# %%
KEYS = [
    "loss", "val_loss",
    "sparse_categorical_accuracy",
    "val_sparse_categorical_accuracy"
]
fig, axs = plt.subplots(2, 2, figsize=(16, 12))
for e in [19, 29, 39, 49, 59, 69, 79, 89, 99]:
    d = np.load("results/choice_20/period_{}/conv_train.npz".format(e))
    for ax, val in zip([*axs[0], *axs[1]], KEYS):
        y_val = np.log(d[val]) if val.endswith("loss") else d[val]
        plot.plot_band(ax, np.arange(25), y_val, label=e)

for ax in [*axs[0], *axs[1]]:
    ax.set_xticks(np.arange(25))
    ax.set_xlabel("Epoch")

axs[1][1].legend()

axs[0][0].set_ylabel("Log Training Loss")
axs[0][1].set_ylabel("Log Validation Loss")
axs[1][0].set_ylabel("Training Accuracy")
axs[1][1].set_ylabel("Validation Accuracy")
# Out:
# Text(0, 0.5, 'Validation Accuracy')
