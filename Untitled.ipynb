# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

import plot

# %%
fig, axs = plt.subplots(2, 2, figsize=(16, 12))
plot.plot_phase(["adam", "choice-20x25C", "choice-20x50C", "choice-20x25C-hard"], axs[0][0], loss=True)
plot.plot_phase(["adam", "choice-20x25M", "choice-20x50M", "choice-20x25M-hard"], axs[0][1], loss=True)
plot.plot_phase(["adam", "rnnprop-20x25C", "rnnprop-20x25M"], axs[1][0], loss=True)
plot.plot_phase(["adam", "rnnprop-20x25CA", "rnnprop-20x25CR", "rnnprop-20x25CAR","rnnprop-20x25CAR-more"], axs[1][1], loss=True)
for row in axs:
    for ax in row:
        ax.legend()
        ax.set_xlim(-5.5, -2)
        ax.set_ylim(-3.5, -2.5)
fig.tight_layout()

# %%
fig, axs = plt.subplots(2, 2, figsize=(16, 12))
plot.plot_stats(["adam", "choice-20x25C", "choice-20x25M"], axs)

# %%
fig, axs = plt.subplots(2, 2, figsize=(16, 12))
plot.plot_stats(["adam", "rnnprop-20x25C", "rnnprop-20x25M"], axs)
