# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

import plot

# %%
fig, axs = plt.subplots(2, 1, figsize=(16, 12))
plot.plot_stats_batch(["adam", "rmsprop"], axs, end=0, use_time=True, sma=25)

# %%
fig, axs = plt.subplots(2, 1, figsize=(16, 12))
plot.plot_stats_batch(["choice_20", "choice_50", "choice_100", "choice_sgd", "adam", "rmsprop"], axs, end=0, use_time=True, sma=25)
# axs[0].set_xlim(0, 60 * 15)
# axs[0].set_ylim(0.38, 0.7)
# axs[1].set_xlim(0, 60 * 15)
# axs[1].set_ylim(0.4, 1.0)

# %%
fig, axs = plt.subplots(2, 1, figsize=(16, 12))
plot.plot_stats_batch(["choice_20", "choice_50", "choice_100", "choice_deeper", "choice_hard", "adam", "rmsprop"], axs, end=0, use_time=False, sma=25)
axs[0].set_xlim(0, 1000)
axs[0].set_ylim(-2.5, 1)
axs[1].set_xlim(0, 1000)
axs[1].set_ylim(0.7, 1)
# Out:
# (0.7, 1)

# %%
df = np.load("baseline/adam/conv_train.npz")

# %%
for x in df["sparse_categorical_accuracy"]:
    plt.plot(x)
